# %%
# %%writefile requirements.txt
# streamlit
# pandas
# scikit-learn
# pdfplumber
# PyMuPDF
# spacy
# python-dotenv
# Out:
# Overwriting requirements.txt

# %%
# %%writefile .gitignore
# __pycache__/
# *.pyc
# .ipynb_checkpoints/
# .env
# Out:
# Writing .gitignore
